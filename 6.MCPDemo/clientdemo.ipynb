# %%
print("MCP Demo")
# Out:
# MCP Demo

# %%
REMOTE_HOST = "http://api.githubcopilot.com/mcp"
TOOLSETS = "respos, issues, pull_requests, context, users, git"
SERVER_NAME = "github"

# %%
def build_github_connection(token)-> dict:
    headers = {
        "X-MCP-Toolsets": TOOLSETS,
    }
    return {
        SERVER_NAME: {
            "token": token,
            "headers": headers,
        }
    }

def get_github_repos(connection_dict)-> list:
